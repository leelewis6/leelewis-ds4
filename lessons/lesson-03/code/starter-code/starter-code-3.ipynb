# %% [markdown]
# # Lesson 3 Codealong
# Instructor: Amy Roberts, PhD

# %%
#General imports
from sklearn import datasets
from sklearn import metrics
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Part 1. Basic Stats
#
#     Methods available include:
# 		.min() - Compute minimum value
# 		.max() - Compute maximum value
# 		.mean() - Compute mean value
# 		.median() - Compute median value
#         .mode() - Compute mode value(s)
# 		.count() - Count the number of observations

# %% [markdown]
# #### Read in the examples

# %%
df = pd.DataFrame({'example1' : [18, 24, 17, 21, 24, 16, 29, 18], 'example2' : [75, 87, 49, 68, 75, 84, 98, 92], 'example3' : [55, 47, 38, 66, 56, 64, 44, 39] })
print (df)
# Out:
#    example1  example2  example3
# 0        18        75        55
# 1        24        87        47
# 2        17        49        38
# 3        21        68        66
# 4        24        75        56
# 5        16        84        64
# 6        29        98        44
# 7        18        92        39

# %% [markdown]
# #### Instructor example: Calculate the mean for each coloumn

# %%
df.mean()
# Out:
# example1    20.875
# example2    78.500
# example3    51.125
# dtype: float64

# %% [markdown]
# #### Students: Calculate median, mode, max, min for example
#
# Note: All answers should match your hand calculations

# %%
#maximum
df.max(
)
# Out:
# example1    29
# example2    98
# example3    66
# dtype: int64

# %%
#minimum
df.min()
# Out:
# example1    16
# example2    49
# example3    38
# dtype: int64

# %%
#median
df.median()
# Out:
# example1    19.5
# example2    79.5
# example3    51.0
# dtype: float64

# %%
#mode
df.mode()
# Out:
#    example1  example2  example3
# 0        18      75.0       NaN
# 1        24       NaN       NaN

# %%
df.count()
# Out:
# example1    8
# example2    8
# example3    8
# dtype: int64

# %% [markdown]
# ### Part 2. Box Plot

# %% [markdown]
# #### Instructor: Interquartile range

# %%
print "50% Quartile:"
print df.quantile(.50) 
print "Median (red line of the box)"
print df.median()
# Out:
# 50% Quartile:
# example1    19.5
# example2    79.5
# example3    51.0
# dtype: float64
# Median (red line of the box)
# example1    19.5
# example2    79.5
# example3    51.0
# dtype: float64

# %%
print"25% (bottome of the box)"
print df.quantile(0.25)
print"75% (top of the box)"
print df.quantile(0.75)
# Out:
# 25% (bottome of the box)
# example1    17.75
# example2    73.25
# example3    42.75
# dtype: float64
# 75% (top of the box)
# example1    24.00
# example2    88.25
# example3    58.00
# dtype: float64

# %%
df['example1'].plot(kind='box')

# %% [markdown]
# #### Student: Create plots for examples 2 and 3 and check the quartiles

# %%
df['example2'].plot(kind='box')

# %%
zscore = df.apply(lambda x: (x - x.mean()) / x.std())

print zscore.example2.sort().inplace
# Out:
# /Users/leelewis/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-cee3f80936e7> in <module>()
#       1 zscore = df.apply(lambda x: (x - x.mean()) / x.std())
#       2
# ----> 3 print zscore.example2.sort().inplace
#       4
#       5
#
# /Users/leelewis/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in sort(self, axis, ascending, kind, na_position, inplace)
#    1784
#    1785         return self.sort_values(ascending=ascending, kind=kind,
# -> 1786                                 na_position=na_position, inplace=inplace)
#    1787
#    1788     def order(self, na_last=None, ascending=True, kind='quicksort',
#
# /Users/leelewis/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1683         # GH 5856/5853
#    1684         if inplace and self._is_cached:
# -> 1685             raise ValueError("This Series is a view of some other array, to "
#    1686                              "sort in-place you must create a copy")
#    1687
#
# ValueError: This Series is a view of some other array, to sort in-place you must create a copy

# %%
df['example3'].plot(kind='box')

# %% [markdown]
# #### What does the cross in example 2 represent?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Part 3. Standard Deviation and Variance

# %% [markdown]
# **Variance:** The variance is how much the predictions for a given point vary between different realizations of the model.
#
# **Standard Deviation:** The square root of the variance

# %% [markdown]
# <img(src='../../assets/images/biasVsVarianceImage.png', style="width: 30%; height: 30%")>

# %% [markdown]
# #### In Pandas
# 	Methods include:
# 		.std() - Compute Standard Deviation
# 		.var() - Compute variance

# %% [markdown]
# #### Let's calculate variance by hand first.
# <img(src='../../assets/images/samplevarstd.png', style="width: 50%; height: 50%")>

# %%
#example1
mean = df["example1"].mean()
n= df["example1"].count()

print df["example1"]
print mean
print n
# Out:
# 0    18
# 1    24
# 2    17
# 3    21
# 4    24
# 5    16
# 6    29
# 7    18
# Name: example1, dtype: int64
# 20.875
# 8

# %%
print df.example1.var()
print df.example1.std()
print df.example1.mean()
# Out:
# 20.125
# 4.48608961123
# 20.875

# %%
# written out by hand for instructional purposes 
#if there is time, have the students refactor this to create a function to calculate variance for any dataset
#find the squared distance from the mean

obs0 = (18 - mean)**2
obs1 = (24 - mean)**2
obs2 = (17 - mean)**2
obs3 = (21 - mean)**2
obs4 = (24 - mean)**2
obs5 = (16 - mean)**2
obs6 = (29 - mean)**2
obs7 = (18 - mean)**2

print obs0, obs1, obs2, obs3, obs4, obs5, obs6, obs7

#sum each observation's squared distance from the mean 
numerator = obs0 + obs1 + obs2 + obs3 + obs4 + obs5 + obs6 +obs7
denominator = n - 1
variance = numerator/denominator
print numerator 
print denominator
print variance
# Out:
# 8.265625 9.765625 15.015625 0.015625 9.765625 23.765625 66.015625 8.265625
# 140.875
# 7
# 20.125

# %%
# in pandas
print "Variance"
print df["example1"].var()
# Out:
# Variance
# 20.125

# %% [markdown]
# #### Students: Calculate the standard deviation by hand for each sample
#
# Recall that the standard deviation is the square root of the variance.

# %%
#find the variance for each dataset

# %%
#calculate standard deviation by hand

# %%
#now do it with pandas!

# %% [markdown]
# #### Short Cut!

# %%
df.describe()
# Out:
#        example1   example2   example3
# count   8.00000   8.000000   8.000000
# mean   20.87500  78.500000  51.125000
# std     4.48609  15.445758  10.776131
# min    16.00000  49.000000  38.000000
# 25%    17.75000  73.250000  42.750000
# 50%    19.50000  79.500000  51.000000
# 75%    24.00000  88.250000  58.000000
# max    29.00000  98.000000  66.000000

# %% [markdown]
# #### Student: Check understanding
# Which value in the above table is the median?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Part 4: Correlation

# %%
df.corr()
# Out:
#           example1  example2  example3
# example1  1.000000  0.477283 -0.123745
# example2  0.477283  1.000000 -0.057076
# example3 -0.123745 -0.057076  1.000000
