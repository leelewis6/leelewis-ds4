# %% [markdown]
# ## Summary
#
# Objective: Predict home prices given attributes about the homes.
#
# ### Data Summary and Data Cleansing
#
# - The Ames Housing Data Set has 1460 Observations and 80 predictors, exluding the target.
# - The data set was cleansed by converting categorical variables to dummy variables.
# - Null values for integers were filled with the mean value.
#
# ### Exploration
# - The target variable, Sales Price,was slightly skewed. I choose to remove outliers to create a distribution that's closer to normal.
# - I explored GrLivArea and 1stFlrSF. Both features were highly correlated with SalePrice.
# - I removed outliers from both features.
#
# ### Model Selection
# 1. Due to the large number of variables, I used Lasso regression.
# 2. For comparison, I also ran an OLS regression as a baseline
# 3. By using CV, I found the best alpha for Lasso to be 100.
# 4. Lasso yielded a slightly better RMSE.
# 5. Lasso's better performance can be attributed to the removal of non-significant and collinear predictors.
# 6. Lasso RMSE = 20990
# 7. OLS RSME = 23345
#
#
# ### Future Improvements
# - I will continue to enhance this project.
# - I'd like try log transforming the features and target variable.
# - I would also consider using a square root transformation.
# - I plan to do more extensive feature engineering and feature selection
#     - Look at time based attributes, specifically month,  and segment based on seasons
#     - Explore each of the features in more detail and create new features that are more insightful.
# - I'd like to bring in other economic indicators that could have stronger correlations with Sale Price.

# %%
# %matplotlib inline
import pandas as pd
import sklearn.metrics as sm
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LassoCV
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Import Data
train = pd.read_csv('train.csv', low_memory=False)
#test = pd.read_csv('test.csv', low_memory=False)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
# #How many fields have nulls
# counts = train.count()

# #Convert counts to a dataframe
# df = pd.DataFrame({'column':counts.index, 'count': counts.values})

# #Find all of the columns with nulls
# nulls = df[df['count'] < 1460]
# nulls.sort('count', ascending = False)

# #Drop all fields with nulls
# #cleanData = train.drop( nulls.column, axis=1)

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### SalesPrice

# %%
#Remove outliers, based on result of histogram
train = train[train.SalePrice < 500000]

# %%
train['SalePrice'].plot(kind="hist", title = 'SalePrice')

# %%
#Find variables that have strongest correlation to Sales Price
train.corr()['SalePrice'].order(ascending = False)
# Out:
# /Users/leelewis/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: order is deprecated, use sort_values(...)
#   from ipykernel import kernelapp as app
# SalePrice        1.000000
# OverallQual      0.805037
# GrLivArea        0.706899
# GarageCars       0.656849
# GarageArea       0.640492
# TotalBsmtSF      0.630575
# 1stFlrSF         0.610254
# YearBuilt        0.558577
# FullBath         0.553990
# YearRemodAdd     0.538191
# GarageYrBlt      0.510754
# TotRmsAbvGrd     0.506406
# Fireplaces       0.467723
# MasVnrArea       0.451822
# BsmtFinSF1       0.377130
# LotFrontage      0.357076
# WoodDeckSF       0.331816
# OpenPorchSF      0.329707
# 2ndFlrSF         0.297849
# HalfBath         0.284643
# LotArea          0.255867
# BsmtFullBath     0.236647
# BsmtUnfSF        0.212318
# BedroomAbvGr     0.165028
# ScreenPorch      0.081710
# MoSold           0.081447
# 3SsnPorch        0.055882
# PoolArea         0.037845
# BsmtFinSF2      -0.013966
# MiscVal         -0.019694
# YrSold          -0.030906
# BsmtHalfBath    -0.031144
# Id              -0.033944
# LowQualFinSF    -0.060032
# OverallCond     -0.079513
# MSSubClass      -0.082224
# EnclosedPorch   -0.145051
# KitchenAbvGr    -0.145147
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### GrLivArea

# %% [markdown]
# GrLivArea has a strong correation to SalePrice. After plotting the distribution, we find that there are seveal outliers. We remove those outliers, and the skewness is removed.

# %%
train = train[train.GrLivArea  < 3500]

# %%
train.GrLivArea .plot(kind="hist", title = 'GrLivArea ')

# %%
train.plot(kind = 'scatter' , x= 'GrLivArea', y = 'SalePrice')

# %% [markdown]
# ### 1stFlrSF

# %% [markdown]
# The square feet on the first floor has a strong impact on Sales Price.  Again, the distribtuions are skewed, so we remove a few outliers to normalize the distribution.

# %%
#Remove outliers based on visual queues
train = train[train['1stFlrSF'] < 2500]

# %%
train.plot(kind = 'scatter' , x= '1stFlrSF', y = 'SalePrice')

# %%
# The original histogram was Skewed to the left as well. Removing outliers improved the chart, so that
#it's closer to a normal distribution. 

train['1stFlrSF'].plot(kind="hist", title = '1stFlrSF')

# %% [markdown]
# ### Prepare Data for Modeling

# %%
#Create Dummy Variables
df = pd.get_dummies(train)

# %%
#Fill in null values with the mean
data = df.fillna(df.mean())

# %%
#Prepare data for fitting
#Remove the target and the ID. The Id has no significance

X = data.drop(['Id','SalePrice'], axis = 1)
y = data.SalePrice

# %%
#Hold out 30% of the data for testing. 

X_train, X_test, y_train, y_test = train_test_split(X, y , test_size =.3, random_state=20)

# %% [markdown]
# ### Simple linear regression

# %%
# Fit linear model using OLS
lm = linear_model.LinearRegression()

result = lm.fit(X_train,y_train)

# %%
#print 'Coefficients:', result.coef_
# print 'y-intercept:', result.intercept_
print 'R-Squared:', result.score(X_train, y_train)
# Out:
# R-Squared: 0.955283871549

# %%
#Print out the coefficents in order of importance, descending...more important coefficient is first
coef = pd.DataFrame({'coef': result.coef_,'column': X_train.columns})
coef.sort('coef', ascending = False)
# Out:
# /Users/leelewis/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#               coef                 column
# 123   65536.122879         RoofStyle_Shed
# 100   59021.855139        Condition2_PosA
# 201   41993.629612       BsmtFinType2_GLQ
# 85    41937.453960   Neighborhood_StoneBr
# 187   39591.564871            BsmtCond_Po
# 199   32878.352420       BsmtFinType2_ALQ
# 200   32091.878812       BsmtFinType2_BLQ
# 151   31972.646383    Exterior2nd_CmentBd
# 130   31098.599521       RoofMatl_WdShngl
# 203   26643.792700       BsmtFinType2_Rec
# 204   25197.696305       BsmtFinType2_Unf
# 202   24824.685448       BsmtFinType2_LwQ
# 104   24568.680804        Condition2_RRNn
# 190   23476.938909        BsmtExposure_Gd
# 282   23129.399497  SaleCondition_AdjLand
# 61    20973.342804          LandSlope_Mod
# 79    20591.825511   Neighborhood_NridgHt
# 214   20387.649781           HeatingQC_Po
# 76    18954.198068   Neighborhood_NPkVill
# 98    18672.131984       Condition2_Feedr
# 233   18662.960610         Functional_Typ
# 173   17612.952250           ExterCond_Po
# 274   17234.351114           SaleType_Con
# 134   17159.905328    Exterior1st_BrkFace
# 278   16515.501032           SaleType_New
# 53    16242.330321       Utilities_AllPub
# 78    16138.306054   Neighborhood_NoRidge
# 223   15755.983882         KitchenQual_Ex
# 69    15066.074002   Neighborhood_Crawfor
# 142   15009.824167     Exterior1st_Stucco
# ..             ...                    ...
# 286  -14110.137145  SaleCondition_Partial
# 75   -14506.546834     Neighborhood_NAmes
# 36   -15642.815957       MSZoning_C (all)
# 196  -15783.358041       BsmtFinType1_LwQ
# 251  -16225.364920          GarageQual_Po
# 54   -16242.330321       Utilities_NoSeWa
# 70   -16765.069239   Neighborhood_Edwards
# 119  -16960.442678        RoofStyle_Gable
# 256  -16997.652934          GarageCond_Po
# 74   -17607.149480   Neighborhood_Mitchel
# 184  -17886.787078            BsmtQual_TA
# 121  -17954.765268          RoofStyle_Hip
# 180  -19396.272117        Foundation_Wood
# 183  -20688.440428            BsmtQual_Gd
# 120  -20707.467120      RoofStyle_Gambrel
# 141  -21566.758094      Exterior1st_Stone
# 101  -21833.029109        Condition2_PosN
# 128  -24349.247003       RoofMatl_Tar&Grv
# 136  -25166.933153    Exterior1st_CemntBd
# 113  -27354.724968      HouseStyle_2.5Fin
# 239  -28371.357177      GarageType_2Types
# 232  -30608.142379         Functional_Sev
# 221  -31355.501161         Electrical_Mix
# 62   -31740.970615          LandSlope_Sev
# 185  -31745.228612            BsmtCond_Fa
# 186  -32458.860345            BsmtCond_Gd
# 188  -32690.253218            BsmtCond_TA
# 93   -34784.340776        Condition1_RRAe
# 102 -100094.727196        Condition2_RRAe
# 268 -100094.727196       MiscFeature_Gar2
#
# [287 rows x 2 columns]

# %%
#Predit the sales prices on the test data set
predicted = result.predict(X_test)

#create a dataframe to store the test and predicted results
predict_linear = pd.DataFrame({'test':y_test, 'predicted': predicted})

#Root Mean Squared Error for OLS - Linear Regression
print np.sqrt(sm.mean_squared_error(y_test, predicted))
# Out:
# 23345.2912409

# %% [markdown]
# ### Lasso Regresion

# %%
#Use Grid Search to find the best alpha for Lasso Regression

from sklearn import grid_search

alphas = np.logspace(-10, 10, 21)
gs = grid_search.GridSearchCV(
    estimator=linear_model.Lasso(),
    param_grid={'alpha': alphas},
    scoring='mean_squared_error')

lasso_result = gs.fit(X_train, y_train)
# Out:
# /Users/leelewis/anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)

# %%
#Get the best parameters for the Lasso Regression
print gs.best_estimator_
# Out:
# Lasso(alpha=100.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
#fit the model with the parameter from the =CV
lasso = linear_model.Lasso(alpha=100.0, copy_X=True, fit_intercept=True, max_iter=1000,
   normalize=False, positive=False, precompute=False, random_state=None,
   selection='cyclic', tol=0.0001, warm_start=False)

#Fit the model
lasso_result =lasso.fit(X_train, y_train)

# %%
#print 'Coefficients:', lasso_result.coef_
#print 'y-intercept:', lasso_result.intercept_
print 'R-Squared:', lasso_result.score(X_train, y_train)
# Out:
# R-Squared: 0.942686847311

# %%
coef = pd.DataFrame({'coef': lasso_result.coef_,'column': X_train.columns})
coefs_cols = ['column','coef']
coefs = coef[coefs_cols]
coefs.sort('coef',ascending = False)
# Out:
# /Users/leelewis/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                     column          coef
# 85    Neighborhood_StoneBr  31252.525088
# 69    Neighborhood_Crawfor  20591.148927
# 223         KitchenQual_Ex  19997.973329
# 78    Neighborhood_NoRidge  18745.952245
# 79    Neighborhood_NridgHt  16540.140965
# 166           ExterQual_Ex  15343.467982
# 134    Exterior1st_BrkFace  13688.734701
# 233         Functional_Typ  12860.538683
# 190        BsmtExposure_Gd  11664.949864
# 278           SaleType_New  11383.432336
# 90         Condition1_Norm   8564.900598
# 84    Neighborhood_Somerst   8346.834791
# 3              OverallQual   7753.982425
# 66    Neighborhood_BrkSide   6269.100013
# 56       LotConfig_CulDSac   6025.480824
# 105          BldgType_1Fam   5375.636013
# 4              OverallCond   5219.661346
# 142     Exterior1st_Stucco   4714.150550
# 242     GarageType_BuiltIn   4188.717310
# 181            BsmtQual_Ex   3883.438258
# 106        BldgType_2fmCon   3806.216738
# 16            BsmtFullBath   3584.849010
# 23              Fireplaces   3456.829676
# 195       BsmtFinType1_GLQ   2932.729233
# 61           LandSlope_Mod   2932.104238
# 50         LandContour_HLS   2385.019624
# 164        MasVnrType_None   2323.717664
# 177       Foundation_PConc   2146.060367
# 211           HeatingQC_Ex   1962.887861
# 234         FireplaceQu_Ex   1647.961926
# ..                     ...           ...
# 128       RoofMatl_Tar&Grv  -1601.315331
# 226         KitchenQual_TA  -1799.943734
# 162      MasVnrType_BrkCmn  -1943.947182
# 272           SaleType_COD  -2159.039608
# 175      Foundation_BrkTil  -2382.920719
# 252          GarageQual_TA  -2542.181541
# 192        BsmtExposure_No  -2593.674862
# 68    Neighborhood_CollgCr  -2725.691269
# 280            SaleType_WD  -2735.252493
# 51         LandContour_Low  -2772.481565
# 264            Fence_GdPrv  -2927.947309
# 71    Neighborhood_Gilbert  -3086.261103
# 40             MSZoning_RM  -3095.581383
# 70    Neighborhood_Edwards  -3129.986714
# 137    Exterior1st_HdBoard  -3172.477733
# 144    Exterior1st_Wd Sdng  -3526.256548
# 196       BsmtFinType1_LwQ  -3583.906770
# 20            BedroomAbvGr  -4003.025152
# 172           ExterCond_Gd  -4147.025973
# 169           ExterQual_TA  -4339.413293
# 75      Neighborhood_NAmes  -4340.464398
# 93         Condition1_RRAe  -4614.935421
# 156    Exterior2nd_Plywood  -4877.948802
# 249          GarageQual_Fa  -5806.573851
# 21            KitchenAbvGr  -7010.635897
# 184            BsmtQual_TA  -8307.740878
# 74    Neighborhood_Mitchel  -8400.392617
# 281  SaleCondition_Abnorml  -9679.777630
# 183            BsmtQual_Gd -10115.531594
# 62           LandSlope_Sev -11240.458628
#
# [287 rows x 2 columns]

# %%
#Identify the features that lasso kept. 
zero = np.where(lasso_result.coef_==0)
not_zero = np.where(lasso_result.coef_!=0)

#Display most important features
indices = np.where(abs(lasso_result.coef_) >= 5000)
plt.barh(range(len(indices[0])), lasso_result.coef_[indices[0]])
plt.yticks(range(len(indices[0])), X.columns[indices[0]])
plt.title('Most imporant features')

# %%
#Count the number of features lasso excluded 
count_zero = sum([len(t) for t in zero])
count_not_zero = sum([len(t) for t in not_zero])
print ("Features Excluded " + str(count_zero))
print ("Features To Keep " + str(count_not_zero))
# Out:
# Features Excluded 177
# Features To Keep 110

# %%
#Predict sales using lasso
lasso_predicted = lasso_result.predict(X_test)

#Create dataframe with test and predicted values
predict_sales = pd.DataFrame({'test':y_test, 'predicted': lasso_predicted})
predict_sales.head()
# Out:
#           predicted    test
# 1086   91806.570424   83500
# 743   137024.465193  175000
# 19    118163.452856  139000
# 1392  116200.385891  123000
# 1331  120889.168821  132500

# %%
#root mean squared error
np.sqrt(sm.mean_squared_error(y_test, lasso_predicted))
# Out:
# 20990.679709362783
